# %% [markdown]
# ## Harmonic oscillator (Caldeira Leggett + Decoherence)

# %% [markdown]
# ### 1. Launch packages

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import numpy as np
import matplotlib.pyplot as plt
from   numpy import fft      
import scipy.fftpack as fftpack
from scipy.special import laguerre
import h5py

# %%
# Set labels' font size

plt.rcParams.update({'axes.labelsize': 26 })
plt.rcParams.update({'legend.fontsize': 17 })
plt.rcParams.update({'xtick.labelsize': 15 })
plt.rcParams.update({'ytick.labelsize': 15 })

# %% [markdown]
# ### 2. Specify System's Quantum Parameters

# %%
X_gridDIM =  256     # Discretization grid size in X
P_gridDIM =  256     # Discretization grid size in P
        
X_amplitude  = 14    # Window range [-X_amplitude, X_amplitude]
P_amplitude  = 14   # Window range [-P_amplitude, P_amplitude]
        
dt= 0.01             # Time discretization
timeSteps = 1000    # Number of iterations
hbar = 1     # Planck's constant

timeRange     =  np.array(range(0,timeSteps+1))*dt        
print 'Simulation time = ', np.max(timeRange) ,'(a.u.)'
# Out:
# Simulation time =  10.0 (a.u.)

# %% [markdown]
# ### 3. Build discretization resolution & coordinates

# %%
# Discretization resolution

dX =  2.*X_amplitude/float(X_gridDIM)
dP =  2.*P_amplitude/float(P_gridDIM)

dTheta  = 2.*np.pi/(2.*P_amplitude)
Theta_amplitude = dTheta*P_gridDIM/2.

dLambda = 2.*np.pi/(2.*X_amplitude)
Lambda_amplitude = dLambda*X_gridDIM/2.

# Vectors with range of coordinates

X_range      =  fftshift(np.linspace(-X_amplitude      , X_amplitude  -dX , X_gridDIM ))
Lambda_range =  fftshift(np.linspace(-Lambda_amplitude , Lambda_amplitude-dLambda  , X_gridDIM))

P_range      = fftshift(np.linspace(-P_amplitude      , P_amplitude-dP           , P_gridDIM))
Theta_range  = fftshift(np.linspace(-Theta_amplitude  , Theta_amplitude - dTheta , P_gridDIM))

# Matrices of grid of coordinates [p,x]

X      = (X_range)[np.newaxis,:]
P      = (P_range)[:,np.newaxis]
Lambda = (Lambda_range)[np.newaxis,:]
Theta  = (Theta_range)[:,np.newaxis]

# Print resolution features

print "Resolution features : "
print ""
print "dX =", dX ,"                            dP = ",dP
print ""
print "X_amplitude =+-",X_amplitude, "                    P_amplitude = +-",P_amplitude
print ""
print "dLambda =" ,dLambda ,"              dTheta =",dTheta
print ""
print "Lambda_amplitude =+-",Lambda_amplitude,"    Theta_amplitude =+-",Theta_amplitude
# Out:
# Resolution features :
#
# dX = 0.109375                             dP =  0.109375
#
# X_amplitude =+- 14                     P_amplitude = +- 14
#
# dLambda = 0.224399475256               dTheta = 0.224399475256
#
# Lambda_amplitude =+- 28.7231328328     Theta_amplitude =+- 28.7231328328

# %% [markdown]
# ### 4. Set up the Kinetic and Potential terms

# %%
# Potential's parameters in atomic units (a.u.)

mass = 1
omega = 1
a = 0.1

def Kinetic(p):
    """
    Kinetic Energy function   
    """
    return p**2/(2*mass)


def Potential(x):
    """
    Potential  function   
    """
    return 0.5*mass*omega**2*x**2 

            
def dPotentialdx(x):
    """
    dPotential/dx  function   
    """
    return mass*omega**2*x

# %% [markdown]
# ### 4.1 Potential plot

# %%
plt.figure(figsize=(15,8))
plt.plot( fftshift(X_range), fftshift(Potential(X_range)) ,"r" ,lw=4,label = '$V(x)$ ' )
plt.xlabel('$x$')
#plt.grid('on')
#plt.legend(frameon=False)
legend(loc = "upper center", frameon=False)
xlabel("$x (a.u.)$",  fontsize=35)

# %% [markdown]
# ### 5. Plot functions

# %%
def PlotWigner(W):
    """
    Display the Wigner function plot.
    
    W -> Wigner fuction.
    
    H -> Classical Hamiltonian.
    """
    import scipy.fftpack as fftpack
    
    print "Imaginary volume = ",np.sum(np.abs(np.imag(W)))
       
    W = np.real(W)
    
    Classical_hamiltonian = fftshift( Kinetic(P) + Potential(X)  )
    
    W = fftpack.fftshift( W )
    
    plt.figure(figsize=(10,7))
    
    #global_color_max = np.max(W)     # Maximum value used at the colorbar
    #global_color_min = np.min(W)          # Minimum value used at the colorbar
    
    global_color_max = 0.3
    global_color_min = -0.3
    
    # Set the global clor min to 2% of the max
    
    global_color_min = min(global_color_min, -0.02*abs(global_color_max))
               
    zero_position =  abs( global_color_min) / (abs( global_color_max) + abs(global_color_min)) 
    
    wigner_cdict = {'red' 	: 	((0., 0., 0.),
							(zero_position, 1., 1.), 
							(1., 1., 1.)),
					'green' :	((0., 0., 0.),
							(zero_position, 1., 1.),
							(1., 0., 0.)),
					'blue'	:	((0., 1., 1.),
							(zero_position, 1., 1.),
							(1., 0., 0.)) }
    wigner_cmap = matplotlib.colors.LinearSegmentedColormap('wigner_colormap', wigner_cdict, 256)

    fig, ax = plt.subplots(figsize=(12, 5))
    
    x_min = -X_amplitude
    
    x_max = X_amplitude - dX
    
    p_min = -P_amplitude
    
    p_max = P_amplitude - dP
    
    cax = ax.imshow( W ,origin='lower',interpolation='none',
                    extent=[ x_min , x_max, p_min, p_max],
                    vmin= global_color_min, vmax=global_color_max, cmap=wigner_cmap)
    
    cbar = fig.colorbar(cax, ticks=[-0.2,-0.1, 0, 0.1, 0.2 , 0.3])
    
    xlabel("$x  \\ (a.u.) $")
    
    ylabel("$p  \\ (a.u.)$")
    
    ax.contour( Classical_hamiltonian  ,arange(0, 100 , 7 ),origin='lower',
                extent=[x_min,x_max,p_min,p_max],
                linewidths=0.25,colors='k')
    
    print 'min real value of W  = ', np.min( W ), ' max real value of W = ', np.max( W )
    
    print 'Renormalization = ', np.sum( W )*dX*dP
    
    return

# %%
def Marginals_plot(W):
    """
    Plot marginals W_x and W_y 
    """
    import scipy.fftpack as fftpack
    
    print "Imaginary volume:", np.sum(np.imag(W))
    
    W = np.real(W) 
    
    # Marginals W_x
    
    W_x = np.sum( W, axis = 0 )*dP
    
    # Marginals W_p
    
    W_p = np.sum( W, axis = 1 )*dX 
    
    # Plots 
    
    plt.figure(figsize=(20,7))

    ax1 = subplot(121)
    
    plot( ifftshift(X_range) ,fftshift(W_x).real,'r', label = '$ W_{x}$' ) 
        
    xlabel('$x  (a.u.)$')
    
    ylabel('$ W_{x}$')
    
    legend(loc = "upper right")
    

    ax2 = subplot(122)
    
    plot( ifftshift(P_range),fftshift(W_p).real ,'r',label = '$ W_{p} $' )
    
    xlabel('$p  (a.u.)$')
    
    ylabel('$ W_{p} $')
    
    legend(loc = "upper right")
    
    return

# %% [markdown]
# ## 6. Propagation
# ### 6.1 Set the Initial state

# %%
def Wigner_gaussian(x,p,s):
    """
    Wigner function of a Gaussian
    x,p  : center of wave packet
    s    : Standard deviation 
    """
    return np.exp(  -( (X-x)/s )**2 -( s*(P-p) )**2  )


def  Wigner_HarmonicOscillator(n,mass,omega,x,p,X,P):
    """
    Wigner function of the Harmonic oscillator
            Parameters
            x,p  : center of wave packet
            n    : Quantum number  
    """
    r2 = mass*omega**2*((X - x))**2 + ((P - p ))**2/mass 
    return  (-1)**(n)*laguerre(n)( 2*r2  )*np.exp(-r2 )

# %%
n = 0
x_c = 0
p_c = 3


W_init = Wigner_HarmonicOscillator(n,mass,omega,x_c,p_c,X,P)
norm   = np.sum( W_init )*dX*dP
W_init /= norm


# Features

print "Energy",(np.sum(P**2*W_init)*dP*dX)/(2*mass) + np.sum(Potential(X)*W_init)*dP*dX    
print "W, Renormalization norm :",np.sum( W_init )*dX*dP
print "Purity :", 2*np.pi*np.sum(W_init**2)*dX*dP
# Out:
# Energy 5.0
# W, Renormalization norm : 1.0
# Purity : 1.0

# %% [markdown]
# ### 6.2  Initial state plots

# %%
PlotWigner( W_init.real )
xlim([-7,7])
ylim([-7,7])
# Out:
# Imaginary volume =  0.0
# min real value of W  =  7.41355312839e-212  max real value of W =  0.317611242647
# Renormalization =  1.0
# (-7, 7)

# %%
Marginals_plot( W_init )
# Out:
# Imaginary volume: 0.0

# %% [markdown]
# ### 6.3 Wigner Propagator ( 2nd order scheme )

# %% [markdown]
# ### 6.4 Caldeira legget terms

# %%
# Damping parameter

gamma = 0.04 #1e-2

# %%
def Product_ThetaP( LW, W):
    
    LW[:] = W   #Avoiding the allocation of new memory.
    LW[:] *= P
    
    LW[:] = fftpack.fft( LW, axis = 0 )    
    
    LW[:] *= Theta
    
    LW[:]  = fftpack.ifft( LW, axis = 0 )
    
    LW[:] *= 1j  # At thi stage, this should be real up to numerical noise
    
    #LW[:] = np.real(LW)+0j   # Making sure this does not add complex noise 
    
    #print ' max complex LW ', np.abs(LW.imag).max()

# %%
def CaldeiraDissipatorOrder3( dt,gammaDamping, LW, LW_temp, W):
    # This function returns W by reference
    

    Product_ThetaP( LW_temp , W )
           
    LW[:] = 2./3.*dt*gammaDamping * LW_temp + W
        
    Product_ThetaP( LW_temp , LW )
    LW[:] =  2./2.*dt *gammaDamping * LW_temp + W

    Product_ThetaP( LW_temp , LW )
    W[:]  =  2.*dt *gammaDamping * LW_temp + W

# %% [markdown]
# ### 6.5 Propagator

# %%
# Set the inital state to be propagated

W = W_init.copy() + 0j

# Propagators factors

expPLambda = np.exp(-1j*dt*P*Lambda/mass)

expPotential =  np.exp( -1j*(dt/2) * ( Potential(X-hbar*Theta/2.) \
                                      - Potential(X+hbar*Theta/2.) )/hbar  )

expDecoherence = np.exp(-gamma*Theta*Theta*dt )

# %%
# Lists to save expectation values

data_Expectation_X=[np.sum(X*W)*dP*dX]

data_Expectation_X2=[np.sum(X**2*W)*dP*dX]

data_Expectation_P=[np.sum(P*W)*dP*dX]

data_Expectation_P2=[np.sum(P**2*W)*dP*dX]

data_Expectation_XP=[np.sum(X*P*W)*dP*dX]

data_Expectation_PX=[np.sum(P*X*W)*dP*dX]

#------------------------------------------------------

data_Expectation_F=[-1*np.sum(dPotentialdx(X)*W)*dP*dX]



data_Expectation_PdVdX=[ np.sum( P*dPotentialdx(X)*W )*dP*dX  ]

data_Expectation_XdVdX=[ np.sum(X*dPotentialdx(X)*W)*dP*dX ]

data_Expectation_V=[ np.sum( Potential(X) *W)*dP*dX ]



#-------------------------------------------------------

data_NegArea = [np.sum(W[np.nonzero( W.real < 0. )]).real*dP*dX]

data_Integral_W2 = [np.sum(W**2)*dX*dP]

data_W_GP_1 = [W]

data_W_GP_1_max = [np.max(W.real)]

data_W_GP_1_min = [np.min(W.real)]

# temporary states
LW      = W_init.copy() + 0j
LW_temp = W_init.copy() + 0j

# Propagator


for tIndex in range(1,timeSteps+1):
    #if tIndex%100==0:
     #   print '  tIndex  = ', tIndex         
          
    # p x -> theta x
    
    W = fftpack.fft( W, axis = 0 )
    
    W *= expPotential
            
    # theta x  -> p x
    
    W = fftpack.ifft( W, axis = 0 )
    
    # p x  ->  p lambda 
    
    W = fftpack.fft( W, axis = 1 )
    
    W *=expPLambda
    
    # p lambda -> p x 
    
    W = fftpack.ifft( W, axis = 1 )
      
    # p x -> theta x
    
    W = fftpack.fft( W, axis = 0 )
    
    W *= expPotential
    
    
    # theta x -> p x
    
    W = fftpack.ifft( W, axis = 0 )
    
    # Caldeira-Legget dissipator
    
    #W = expCaldeiraLegget_OrderNth( W , gamma, 4 )
    CaldeiraDissipatorOrder3( dt, gamma, LW, LW_temp, W)
    
    W *= expDecoherence
    
    W /= np.sum(W)*dX*dP
    
    print ' max complex W ', np.abs(W.imag).max()
    
    # Current expectations values
        
    Expectation_X = np.sum(X*W)*dP*dX
    
    Expectation_X2=np.sum(X**2*W)*dP*dX
    
    Expectation_P = np.sum(P*W)*dP*dX
    
    Expectation_P2= np.sum(P**2*W)*dP*dX
    
    Expectation_XP= np.sum(X*P*W)*dP*dX
    
    Expectation_PX= np.sum(P*X*W)*dP*dX
    
    #---------------------------------------------------
            
    Expectation_F= -1*np.sum(dPotentialdx(X)*W)*dP*dX 
        
    Expectation_XdVdX= np.sum(X*dPotentialdx(X)*W)*dP*dX 
    
    Expectation_PdVdX= np.sum(P*dPotentialdx(X)*W)*dP*dX 
    
    Expectation_V = np.sum( Potential(X)*W )*dP*dX
    
    
    
    #---------------------------------------------------
    
    Integral_W2 = np.sum(W**2)*dX*dP
    
    NegArea = np.sum(W[np.nonzero( W.real < 0. )]).real*dP*dX
    
    W_GP_1_max = np.max(W.real)
    
    W_GP_1_min = np.min(W.real)
        
    # Store the expectation values
      
    data_Expectation_X.append(Expectation_X)  
    
    data_Expectation_X2.append(Expectation_X2) 
    
    data_Expectation_P.append(Expectation_P)
    
    data_Expectation_P2.append(Expectation_P2) 
    
    data_Expectation_XP.append(Expectation_XP) 
    
    data_Expectation_PX.append(Expectation_PX)
    
    data_Expectation_F.append(Expectation_F)   
    
    data_Expectation_XdVdX.append(Expectation_XdVdX) 
    
    data_Expectation_PdVdX.append(Expectation_PdVdX)
    
    data_Expectation_V.append(Expectation_V)
       
    data_Integral_W2.append(Integral_W2)
    
    data_NegArea.append(NegArea)
    
    data_W_GP_1.append(W)
    
    data_W_GP_1_max.append(W_GP_1_max)
    
    data_W_GP_1_min.append(W_GP_1_min)
    
#---Final state

W_end = W 

data_W_GP_1_max = np.array(data_W_GP_1_max)
data_W_GP_1_min = np.array(data_W_GP_1_min)


print ' "W_end" renormalization norm: ',np.sum(W_end)*dX*dP
print""
print np.max(data_W_GP_1_max)
print np.min(data_W_GP_1_min)

data_W_GP_1               = np.array(data_W_GP_1)
data_Expectation_X      = np.array(data_Expectation_X).real
data_Expectation_X2     = np.array(data_Expectation_X2).real
data_Expectation_P      = np.array(data_Expectation_P).real
data_Expectation_P2     = np.array(data_Expectation_P2).real
data_Expectation_XP     = np.array(data_Expectation_XP).real
data_Expectation_PX     = np.array(data_Expectation_PX).real
data_Expectation_F      = np.array(data_Expectation_F).real
data_Expectation_XdVdX  = np.array(data_Expectation_XdVdX).real
data_Expectation_PdVdX  = np.array(data_Expectation_PdVdX).real
data_Expectation_V      = np.array(data_Expectation_V).real
# Out:
#  max complex W  7.93173144015e-17
#  max complex W  1.45359889238e-16
#  max complex W  1.93458111388e-16
#  max complex W  2.4140637466e-16
#  max complex W  2.99418964693e-16
#  max complex W  3.42179919292e-16
#  max complex W  3.95506724462e-16
#  max complex W  4.59191240361e-16
#  max complex W  5.16335344952e-16
#  max complex W  5.40882872896e-16
#  max complex W  5.74694524693e-16
#  max complex W  6.13334933468e-16
#  max complex W  6.55603046493e-16
#  max complex W  7.4439705761e-16
#  max complex W  8.3858095553e-16
#  max complex W  8.93785078192e-16
#  max complex W  9.19791120077e-16
#  max complex W  9.64911555199e-16
#  max complex W  1.03399055953e-15
#  max complex W  1.0695559359e-15
#  max complex W  1.15316092197e-15
#  max complex W  1.23033951331e-15
#  max complex W  1.25489127659e-15
#  max complex W  1.33291205894e-15
#  max complex W  1.40067043117e-15
#  max complex W  1.48053241162e-15
#  max complex W  1.55453009973e-15
#  max complex W  1.60942545942e-15
#  max complex W  1.66945336413e-15
#  max complex W  1.73039896472e-15
#  max complex W  1.76708118313e-15
#  max complex W  1.80313129082e-15
#  max complex W  1.82271478841e-15
#  max complex W  1.84946554948e-15
#  max complex W  1.86952361567e-15
#  max complex W  1.89797029558e-15
#  max complex W  1.92329779251e-15
#  max complex W  1.94587662082e-15
#  max complex W  1.95438979281e-15
#  max complex W  1.97085173929e-15
#  max complex W  1.97701487673e-15
#  max complex W  2.00398593455e-15
#  max complex W  2.01842742097e-15
#  max complex W  2.01546448196e-15
#  max complex W  2.01833617978e-15
#  max complex W  2.01990933173e-15
#  max complex W  1.99354965264e-15
#  max complex W  1.98539448846e-15
#  max complex W  2.04100891359e-15
#  max complex W  2.09105271411e-15
#  max complex W  2.12966629734e-15
#  max complex W  2.15082203432e-15
#  max complex W  2.17455364671e-15
#  max complex W  2.18703530492e-15
#  max complex W  2.1998816122e-15
#  max complex W  2.20776683695e-15
#  max complex W  2.20762842989e-15
#  max complex W  2.21243068326e-15
#  max complex W  2.21913052826e-15
#  max complex W  2.22560519379e-15
#  max complex W  2.23443192861e-15
#  max complex W  2.23057209612e-15
#  max complex W  2.22723699808e-15
#  max complex W  2.23019520796e-15
#  max complex W  2.27925447518e-15
#  max complex W  2.3322255116e-15
#  max complex W  2.37232698839e-15
#  max complex W  2.40626617814e-15
#  max complex W  2.43368572276e-15
#  max complex W  2.46290504003e-15
#  max complex W  2.47033151937e-15
#  max complex W  2.48987332497e-15
#  max complex W  2.50096187091e-15
#  max complex W  2.51613962762e-15
#  max complex W  2.5097807209e-15
#  max complex W  2.50494442166e-15
#  max complex W  2.49482931892e-15
#  max complex W  2.48644927288e-15
#  max complex W  2.48599535604e-15
#  max complex W  2.48509979859e-15
#  max complex W  2.5100404078e-15
#  max complex W  2.5382030832e-15
#  max complex W  2.56465718066e-15
#  max complex W  2.60437575349e-15
#  max complex W  2.62315060124e-15
#  max complex W  2.72663436825e-15
#  max complex W  2.81192957485e-15
#  max complex W  2.81642057478e-15
#  max complex W  2.82089796434e-15
#  max complex W  2.83086554389e-15
#  max complex W  2.80607170751e-15
#  max complex W  2.77805331644e-15
#  max complex W  2.77224968092e-15
#  max complex W  2.75756044386e-15
#  max complex W  2.80359724042e-15
#  max complex W  2.85392024119e-15
#  max complex W  2.89359469922e-15
#  max complex W  2.91072675975e-15
#  max complex W  2.91926307803e-15
#  max complex W  2.9118534842e-15
#  max complex W  2.93315279559e-15
#  max complex W  2.89828053833e-15
#  max complex W  2.89121412923e-15
#  max complex W  2.89761051734e-15
#  max complex W  2.88829507009e-15
#  max complex W  2.88792799278e-15
#  max complex W  2.9271977816e-15
#  max complex W  2.94217575896e-15
#  max complex W  2.91283175759e-15
#  max complex W  2.86714911482e-15
#  max complex W  2.82546491578e-15
#  max complex W  2.9099876099e-15
#  max complex W  2.97952493514e-15
#  max complex W  2.99483378445e-15
#  max complex W  3.05771725066e-15
#  max complex W  3.19205314579e-15
#  max complex W  3.31461614898e-15
#  max complex W  3.32236437433e-15
#  max complex W  3.26901018355e-15
#  max complex W  3.30414280237e-15
#  max complex W  3.34603462966e-15
#  max complex W  3.30123844595e-15
#  max complex W  3.19551586185e-15
#  max complex W  3.14287297515e-15
#  max complex W  3.15718411336e-15
#  max complex W  3.15714914482e-15
#  max complex W  3.17648878817e-15
#  max complex W  3.17875157517e-15
#  max complex W  3.23566115278e-15
#  max complex W  3.21882456117e-15
#  max complex W  3.23539127606e-15
#  max complex W  3.21536863849e-15
#  max complex W  3.36207468018e-15
#  max complex W  3.45186016355e-15
#  max complex W  3.4766736792e-15
#  max complex W  3.45027377401e-15
#  max complex W  3.52543798235e-15
#  max complex W  3.62690855972e-15
#  max complex W  3.65145257561e-15
#  max complex W  3.59174615511e-15
#  max complex W  3.55173304456e-15
#  max complex W  3.68665740778e-15
#  max complex W  3.73889656448e-15
#  max complex W  3.71737888717e-15
#  max complex W  3.63086793101e-15
#  max complex W  3.64319410168e-15
#  max complex W  3.6832842801e-15
#  max complex W  3.71064053593e-15
#  max complex W  3.83124547178e-15
#  max complex W  3.96705905738e-15
#  max complex W  4.05576001456e-15
#  max complex W  4.11163739836e-15
#  max complex W  4.06520200436e-15
#  max complex W  4.12244526754e-15
#  max complex W  4.16761969435e-15
#  max complex W  4.21703988807e-15
#  max complex W  4.20423121695e-15
#  max complex W  4.17313119321e-15
#  max complex W  4.14224481242e-15
#  max complex W  4.16399171401e-15
#  max complex W  4.21265296306e-15
#  max complex W  4.21158637039e-15
#  max complex W  4.14646862179e-15
#  max complex W  4.10467642425e-15
#  max complex W  4.17101384668e-15
#  max complex W  4.19969149754e-15
#  max complex W  4.21657723856e-15
#  max complex W  4.15553514392e-15
#  max complex W  4.08195779382e-15
#  max complex W  4.0685962232e-15
#  max complex W  4.11866945608e-15
#  max complex W  4.09589580857e-15
#  max complex W  4.07938512925e-15
#  max complex W  4.1575019654e-15
#  max complex W  4.14552514975e-15
#  max complex W  4.06124077026e-15
#  max complex W  4.05628385012e-15
#  max complex W  4.08370517589e-15
#  max complex W  4.12147799604e-15
#  max complex W  4.06658610967e-15
#  max complex W  4.05414044545e-15
#  max complex W  4.03501624913e-15
#  max complex W  3.99479447005e-15
#  max complex W  4.05063935061e-15
#  max complex W  4.10304412823e-15
#  max complex W  4.06861649343e-15
#  max complex W  4.21580199346e-15
#  max complex W  4.38190408175e-15
#  max complex W  4.45403565634e-15
#  max complex W  4.42079467264e-15
#  max complex W  4.27484242236e-15
#  max complex W  4.24212746224e-15
#  max complex W  4.29714087123e-15
#  max complex W  4.31761785033e-15
#  max complex W  4.29497244727e-15
#  max complex W  4.18119063337e-15
#  max complex W  4.10422753833e-15
#  max complex W  4.08527975429e-15
#  max complex W  4.09863225304e-15
#  max complex W  4.2826906434e-15
#  max complex W  4.47896731052e-15
#  max complex W  4.60007019622e-15
#  max complex W  4.64937044476e-15
#  max complex W  4.58260478876e-15
#  max complex W  4.43230608308e-15
#  max complex W  4.2827928328e-15
#  max complex W  4.37186663248e-15
#  max complex W  4.50941492555e-15
#  max complex W  4.52382670596e-15
#  max complex W  4.47578664479e-15
#  max complex W  4.42945688656e-15
#  max complex W  4.39150297397e-15
#  max complex W  4.57334374493e-15
#  max complex W  4.74585834614e-15
#  max complex W  4.86499218147e-15
#  max complex W  4.88158946845e-15
#  max complex W  4.75388439072e-15
#  max complex W  4.68554631043e-15
#  max complex W  4.65214312934e-15
#  max complex W  4.72248795855e-15
#  max complex W  4.85981157171e-15
#  max complex W  4.99257215992e-15
#  max complex W  5.06286332115e-15
#  max complex W  5.04632906318e-15
#  max complex W  4.86720142344e-15
#  max complex W  4.88656674565e-15
#  max complex W  5.08585104365e-15
#  max complex W  5.25226363997e-15
#  max complex W  5.33976548982e-15
#  max complex W  5.24072229494e-15
#  max complex W  5.03226258449e-15
#  max complex W  4.95272143842e-15
#  max complex W  5.1353936246e-15
#  max complex W  5.29503221402e-15
#  max complex W  5.4210304744e-15
#  max complex W  5.38475032388e-15
#  max complex W  5.2296307488e-15
#  max complex W  5.23368722472e-15
#  max complex W  5.14105405473e-15
#  max complex W  5.29771487228e-15
#  max complex W  5.42741160255e-15
#  max complex W  5.44320335143e-15
#  max complex W  5.40691705637e-15
#  max complex W  5.46302778807e-15
#  max complex W  5.5155202292e-15
#  max complex W  5.59881254304e-15
#  max complex W  5.68059728607e-15
#  max complex W  5.78305894302e-15
#  max complex W  5.85422611974e-15
#  max complex W  5.94639797506e-15
#  max complex W  6.02306609982e-15
#  max complex W  6.13998829523e-15
#  max complex W  6.17426132178e-15
#  max complex W  6.23490476199e-15
#  max complex W  6.25970345194e-15
#  max complex W  6.28155848682e-15
#  max complex W  6.31069214252e-15
#  max complex W  6.31126625129e-15
#  max complex W  6.35238741789e-15
#  max complex W  6.3904023175e-15
#  max complex W  6.47374524211e-15
#  max complex W  6.56629437499e-15
#  max complex W  6.65959241666e-15
#  max complex W  6.67486501986e-15
#  max complex W  6.66307063174e-15
#  max complex W  6.62831918618e-15
#  max complex W  6.57221035046e-15
#  max complex W  6.61285382393e-15
#  max complex W  6.79959979611e-15
#  max complex W  6.9506794606e-15
#  max complex W  6.98119071722e-15
#  max complex W  6.87717422198e-15
#  max complex W  6.96457412676e-15
#  max complex W  6.97797938783e-15
#  max complex W  6.93277412181e-15
#  max complex W  6.7559146651e-15
#  max complex W  6.53531651045e-15
#  max complex W  6.33990031458e-15
#  max complex W  6.40532898419e-15
#  max complex W  6.53610413224e-15
#  max complex W  6.53470032676e-15
#  max complex W  6.47336146695e-15
#  max complex W  6.61313087541e-15
#  max complex W  6.67760821677e-15
#  max complex W  6.85479175403e-15
#  max complex W  6.9877777212e-15
#  max complex W  7.06403817596e-15
#  max complex W  7.16761362712e-15
#  max complex W  7.21334385765e-15
#  max complex W  7.25690319739e-15
#  max complex W  7.29606298461e-15
#  max complex W  7.44726600623e-15
#  max complex W  7.57076465323e-15
#  max complex W  7.58542662394e-15
#  max complex W  7.54670265049e-15
#  max complex W  7.6906867595e-15
#  max complex W  7.81607107276e-15
#  max complex W  7.90368020749e-15
#  max complex W  7.90801157497e-15
#  max complex W  8.10174923648e-15
#  max complex W  8.25336639257e-15
#  max complex W  8.32200430775e-15
#  max complex W  8.35794524717e-15
#  max complex W  8.49903612476e-15
#  max complex W  8.66792289568e-15
#  max complex W  8.7900068474e-15
#  max complex W  8.86985715071e-15
#  max complex W  8.97693029129e-15
#  max complex W  9.20974501867e-15
#  max complex W  9.35762106032e-15
#  max complex W  9.44490635345e-15
#  max complex W  9.4886242833e-15
#  max complex W  9.63228826408e-15
#  max complex W  9.82092044499e-15
#  max complex W  1.00072330175e-14
#  max complex W  6.64918244601e-14
#  max complex W  6.7061618072e-14
#  max complex W  6.73798026773e-14
#  max complex W  6.83376565587e-14
#  max complex W  6.96479336899e-14
#  max complex W  7.07310371051e-14
#  max complex W  7.16002812432e-14
#  max complex W  7.22055166507e-14
#  max complex W  7.2829489216e-14
#  max complex W  7.32815960079e-14
#  max complex W  7.35848379963e-14
#  max complex W  7.39136745217e-14
#  max complex W  7.42327451988e-14
#  max complex W  7.47831717545e-14
#  max complex W  7.52716679395e-14
#  max complex W  7.66202166709e-14
#  max complex W  7.79120882851e-14
#  max complex W  7.91689866684e-14
#  max complex W  8.03484577655e-14
#  max complex W  8.15418427658e-14
#  max complex W  8.26758281985e-14
#  max complex W  8.37509541633e-14
#  max complex W  8.48325030873e-14
#  max complex W  8.58116923379e-14
#  max complex W  8.67527998261e-14
#  max complex W  8.76224166987e-14
#  max complex W  8.85209170759e-14
#  max complex W  8.93471520431e-14
#  max complex W  9.0107099998e-14
#  max complex W  9.08417167303e-14
#  max complex W  9.15158004854e-14
#  max complex W  9.21514738517e-14
#  max complex W  9.27389914958e-14
#  max complex W  9.32883587726e-14
#  max complex W  9.38013982753e-14
#  max complex W  9.42760082663e-14
#  max complex W  9.47172172393e-14
#  max complex W  9.50942432832e-14
#  max complex W  9.54211786086e-14
#  max complex W  9.57363055748e-14
#  max complex W  9.59628866398e-14
#  max complex W  9.61887597552e-14
#  max complex W  9.63776900863e-14
#  max complex W  9.64943619162e-14
#  max complex W  9.66285230802e-14
#  max complex W  9.67023417602e-14
#  max complex W  9.67667597742e-14
#  max complex W  9.67733652123e-14
#  max complex W  9.67445558081e-14
#  max complex W  9.66769661275e-14
#  max complex W  9.65563493594e-14
#  max complex W  9.64254461852e-14
#  max complex W  9.62478519182e-14
#  max complex W  9.60287676589e-14
#  max complex W  9.57742860073e-14
#  "W_end" renormalization norm:  (1-9.66354608896e-30j)
#
# 1.10906623649
# -4.00821102022e-15

# %% [markdown]
# ### 6.5 Final Wigner state plots

# %%
PlotWigner( W_end.real )
xlim([-7,7])
ylim([-7,7])
# Out:
# Imaginary volume =  0.0
# min real value of W  =  -3.67642242224e-15  max real value of W =  1.10569296116
# Renormalization =  1.0
# (-7, 7)

# %%
Marginals_plot( W_end )
# Out:
# Imaginary volume: -8.07793566946e-28

# %%
plot(  data_Expectation_X, data_Expectation_P )

# %% [markdown]
# ### 7. Energy plots
# ### 7.1 Total energy

# %%
plt.figure(figsize=(10,7))

HamiltonianEnergy = data_Expectation_P2/(2*mass) + data_Expectation_V
                                                  

plot(  timeRange, np.real( HamiltonianEnergy ) ,'b', label = '$ E= \\frac{\\langle p \\rangle^2}{2m} + \\langle V(x)\\rangle  $'  )   


ylim (0,5.5)

xlabel("$Time \\ (a.u.)$")

legend(loc='upper left', bbox_to_anchor=(1,1))

# %% [markdown]
# ### 8. Average values plots

# %%
  
# 1 st:

data_Expectation_dXdt = np.gradient(data_Expectation_X,dt) 
data_Expectation_P_mass = np.array( data_Expectation_P )/mass
    
# 2 nd:

data_Expectation_dPdt =np.gradient(data_Expectation_P,dt)

    
# 3 rd :

data_Expectation_dX2dt = np.gradient(data_Expectation_X2,dt)
data_Expectation_XP_PX_m = 2*np.array(data_Expectation_XP)/mass

# 4 th: 

data_Expectation_dP2dt= np.gradient(data_Expectation_P2,dt)
data_Expectation_pdVdx_dVdxp= -2*np.array(data_Expectation_PdVdX)
    
# Virial:
    
data_Expectation_d_PX_XP_dt = np.array(np.gradient(data_Expectation_XP,dt))+ np.array(np.gradient(data_Expectation_PX,dt))
data_Expectation_virial = 2*np.array(data_Expectation_P2)/mass -2*np.array(data_Expectation_XdVdX)
    
    
# Uncertainty Principle

data_Expectation_sigmaX_sigmaP = np.sqrt(np.array(data_Expectation_X2).real- np.array(data_Expectation_X).real**2) * np.sqrt(np.array(data_Expectation_P2).real - np.array(data_Expectation_P).real**2)  
    
    
# Purity 

data_purity = 2*np.pi*np.array(data_Integral_W2)

# %% [markdown]
# Ehrenfest's theorems:
#
# $$ \frac{d \langle x \rangle }{dt}=\frac{\langle p\rangle}{m}  $$
#
# $$ \frac{d \langle p \rangle}{dt} = -\langle U'(x) \rangle $$
#
# $$ \frac{d \langle x^2 \rangle}{dt} = \frac{1}{m}\langle x p  +  p x \rangle $$
#
# $$ \frac{d \langle p^2 \rangle }{dt} =  - \langle pU'(x) + U'(x)p \rangle $$

# %%
# Plots 

plt.figure(figsize=(24,16))

ax1 = subplot(221)

plot(  timeRange,  data_Expectation_dXdt , 'r',label = '$ \\frac{d}{dt} \\langle x \\rangle $'  )
plot(  timeRange,  data_Expectation_P_mass  ,'k--', label = '$ \\frac{1}{m} \\langle p \\rangle $'  )
xlabel("$Time \\ (a.u.)$")
legend(loc = "upper right")

ax2 = subplot(222)

plot(timeRange, data_Expectation_dPdt  ,'r'   , label = '$ \\frac{d}{dt} \\langle p \\rangle $' )
plot(timeRange, data_Expectation_F , 'k--',label = "$ -\\langle  U'(x) \\rangle $" )
xlabel("$Time \\ (a.u.)$")
legend(loc = "lower right")

ax3 = subplot(223)

plot(timeRange, data_Expectation_dX2dt ,'r',label = '$ \\frac{d}{dt} \\langle x^2 \\rangle $' )
plot(timeRange, data_Expectation_XP_PX_m  ,'k--',label = '$ \\frac{1}{m} \\langle xp   + px \\rangle $' )
xlabel("$Time \\ (a.u.)$")
legend(loc = "lower right")

ax4 = subplot(224)

plot( timeRange, data_Expectation_dP2dt ,'r',label = '$ \\frac{d}{dt} \\langle p^2 \\rangle $' )
plot(timeRange,  data_Expectation_pdVdx_dVdxp,'k--',label = "$ -\\langle pU'(x) + U'(x)p \\rangle $" )
xlabel("$Time \\ (a.u.)$")
legend(loc = "lower right")

# %% [markdown]
# Virial theorem :
# $$ \frac{d }{dt}\langle x p + p x  \rangle  =  \frac{ \\2 \langle p^2 \rangle }{m} - 2 \langle x V'(x) \rangle  $$
# Purity condition:
# $$2\pi \hbar \int W^{2}(x,p)dxdp=1$$
# Uncertainty principle:
# $$  \sigma_x \sigma_p  \geqslant   0.5 $$
